# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from keras.models import load_model
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

# %%
 # Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model('C:/Users/Brahim/Desktop/model1') # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
# load all images into a list
images = []
img_folder = os.path.join('C:/Users/Brahim/Desktop/basedata/test')
img_files = os.listdir(img_folder)
img_files = [os.path.join(img_folder, f) for f in img_files]
# print(img_files)
for img in img_files:
    img = image.load_img(img, target_size=(230, 310))
    plt.imshow(img)
    plt.show()
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    images.append(img)
# stack up images list to pass for prediction
images = np.vstack(images)
# print(images)
classes = model.predict(images)
predictions = []
for x in classes:
    predictions.append(np.argmax(x))
print(predictions[0])
if predictions[0]==0 :
        print('girafe')
elif predictions[0]==1:
        print('lion')
else:
        print('singe')
# Out:
# 0
# girafe

# %%
model2 = load_model('C:/Users/Brahim/Desktop/model2')

# %%
# load all images into a list
imag = []
img_folder1 = os.path.join('C:/Users/Brahim/Desktop/basedata/test')
img_files1 = os.listdir(img_folder1)
img_files1 = [os.path.join(img_folder1, f) for f in img_files1]
# print(img_files)
for img1 in img_files1:
    img1 = image.load_img(img1, target_size=(230, 310))
    plt.imshow(img1)
    plt.show()
    img1 = image.img_to_array(img1)
    img1 = np.expand_dims(img1, axis=0)
    imag.append(img1)
# stack up images list to pass for prediction
imag = np.vstack(imag)
# print(images)
classs = model.predict(imag)
predictions1 = []
for x in classs:
    predictions1.append(np.argmax(x))
print(predictions1[0])
if predictions1[0]==0 :
        print('argent')
elif predictions1[0]==1:
        print('or')
else:
        print('bronze')
# Out:
# 1
# or

# %%
 # Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model('C:/Users/Brahim/Desktop/model2') # path to the SavedModel directory
tflite_model2 = converter.convert()

# Save the model.
with open('model2.tflite', 'wb') as f:
  f.write(tflite_model2)
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
